# %%
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np

# %%
# Set up Column correlation 
from sklearn.feature_selection import mutual_info_classif


def topk_corr(X: pd.DataFrame, A: str, k=100, stop_threshold=0.08, method="pearson") -> pd.Series:
    y = X[A]

    Xn = X.select_dtypes(include="number")

    Xn = Xn.loc[:, Xn.nunique(dropna=True) > 1]
    corrs = Xn.corrwith(y, method=method).dropna()
    top = corrs.abs().sort_values(ascending=False).head(k)
    return top[top >= stop_threshold]

# %% [markdown]
# ### Define MTs and EPs and the routines for testing them, alongside the classic ML evaluation routine

# %%
# Define metamorphic transformations
def perturbation(df, cols):
    df_perturbed = df.copy()
    for col in cols:
        df_perturbed[col] = df[col] + np.random.normal(0, df[col].std(), size=df[col].shape)
    return df_perturbed

def permutation(df, cols):
    df_permuted = df.copy()
    perm = np.random.permutation(len(df))
    df_permuted[cols] = df_permuted[cols].iloc[perm].to_numpy()
    return df_permuted

# %%
# Apply metamorphic testing
def metamorphic_test(model, X_test, y_test, metamorphic_relations, runs=10, sample=5000, debug = False):
    passed = 0
    failed = 0
    for metamorphic in metamorphic_relations:
        target_columns = metamorphic['target'](X_test)
        print(f"Test: {metamorphic['name']}")

        for transformation in metamorphic['transformations']:
            
            print(f"{transformation['name']} test")
            acc_list = []
            for run in range(runs):
    
                data_sample = X_test.sample(n = sample)
                data_labels = y_test.loc[data_sample.index]

                tranf_data = transformation['function'](data_sample, target_columns)
                tranf_labels = y_test.loc[tranf_data.index]

                predictions = model.predict(data_sample)
                accuracy = accuracy_score(data_labels, predictions)

                if not tranf_data.empty:
                # Predictions using the model
                    meta_predictions = model.predict(tranf_data)

                    # Calculate accuracy for this partition
                    meta_accuracy = accuracy_score(tranf_labels, meta_predictions)
                    acc_list.append(abs(meta_accuracy - accuracy))

            mean_diff = np.mean(acc_list)
            if debug:
                print(f"Mean diff: {mean_diff}")
                print(f"Threshold: {transformation['threshold']}")
            if mean_diff < transformation['threshold']:
                print("PASSED ✅")
                passed += 1
            else: 
                print("FAILED ❌")
                failed += 1
            print()
    return passed, failed

# %%
# Apply equivalent partitioning
def equivalence_partitioning_test(model, X_test, y_test, partition_tests, runs=10, sample=5000, debug = False):
    passed = 0
    failed = 0
    for test in partition_tests:
        
        print(f'Partition on : {test["name"]}')
        
        part_means = []
        for partition in test['partitions']:

            #print(f'Partition: {partition['name']}')
            acc_list = []
            means = []
            for run in range(runs):
                
                data_sample = X_test.sample(n = sample)

                partition_data = data_sample[partition["condition"](data_sample)]
                partition_labels = y_test.loc[partition_data.index]  

                if not partition_data.empty:
                    predictions = model.predict(partition_data)

                    accuracy = accuracy_score(partition_labels, predictions)
                    acc_list.append(accuracy)
                    means.append(np.mean(predictions))

            #print(f"Average accuracy: {np.mean(acc_list)}")
            part_means.append(np.mean(means))
            #print(f"Deviation in accuracy: {np.std(acc_list)}")
        mean = sum(part_means)/len(part_means)
        max_diff = abs(max(part_means)-min(part_means))
        if debug:
            print(f"Max diff: {max_diff}")
            print(f"Threshold: {test['threshold']}")
        if max_diff < test['threshold']:
            passed +=1
            print("PASSED ✅")
        else:
            failed +=1 
            print("FAILED ❌")
        print()
    return passed, failed

# %%
# Set up metamorphic relationships
metamorphic_relations=[
    {'name': 'age', 'target': lambda df: topk_corr(df, "person_age_at_investigation").index.tolist(),
      'transformations': [{'name': 'permutation', 'function': permutation, 'threshold': 0.03}, {'name': 'perturbation', 'function': perturbation, 'threshold': 0.02}]},
    {'name': 'language', 'target': lambda df: topk_corr(df, "personal_qualities_days_since_language_requirement").index.tolist(),
      'transformations': [{'name': 'permutation', 'function': permutation, 'threshold': 0.03}, {'name': 'perturbation', 'function': perturbation, 'threshold': 0.01}]},
    {'name': 'medical', 'target': lambda df: topk_corr(df, "exemption_days_hist_due to_your_medical_conditions").index.tolist(),
      'transformations': [{'name': 'permutation', 'function': permutation, 'threshold': 0.02}, {'name': 'perturbation', 'function': perturbation, 'threshold': 0.02}]},
    {'name': 'children', 'target': lambda df: topk_corr(df, "relationship_child_current_number").index.tolist(),
      'transformations': [{'name': 'permutation', 'function': permutation, 'threshold': 0.02}]},
    {'name': 'social', 'target': lambda df: topk_corr(df, "pla_history_social_effort").index.tolist(),
      'transformations': [{'name': 'permutation', 'function': permutation, 'threshold': 0.02}]},
    {'name': 'gender', 'target': lambda df: topk_corr(df, "person_gender_woman").index.tolist(),
      'transformations': [{'name': 'permutation', 'function': permutation, 'threshold': 0.02}]},
]

# %%
# Set up equivalent partitions

def quartile_partition(X, col, quart: int):
    if quart not in [0,1,2,3]:
        raise Exception('quart needs to be a quartile')
    match quart:
        case 0: return X[col] < X[col].quantile(0.25)
        case 1: return X[col].between(X[col].quantile(0.25), X[col].quantile(0.5), inclusive = 'left')
        case 2: return X[col].between(X[col].quantile(0.5), X[col].quantile(0.75), inclusive = 'left')
        case 3: return X[col] >= X[col].quantile(0.75)

partition_tests = [
    {
    # Related to obstacles
    'name': 'age',
    'partitions': [ 
        {"name": "q0", "condition": lambda df: quartile_partition(df, 'person_age_at_investigation', 0)},
        {"name": "q1", "condition": lambda df: quartile_partition(df, 'person_age_at_investigation', 1)},
        {"name": "q2", "condition": lambda df: quartile_partition(df, 'person_age_at_investigation', 2)},
        {"name": "q3", "condition": lambda df: quartile_partition(df, 'person_age_at_investigation', 3)},
    ],
    "threshold": 0.1},{
    'name': 'language',
    'partitions': [
        {"name": "q0", "condition": lambda df: quartile_partition(df, 'personal_qualities_days_since_language_requirement', 0)},
        {"name": "q1", "condition": lambda df: quartile_partition(df, 'personal_qualities_days_since_language_requirement', 1)},
        {"name": "q2", "condition": lambda df: quartile_partition(df, 'personal_qualities_days_since_language_requirement', 2)},
        {"name": "q3", "condition": lambda df: quartile_partition(df, 'personal_qualities_days_since_language_requirement', 3)},
    ],
    "threshold": 0.05},{
    'name': 'medical',
    'partitions': [
        {"name": "q0", "condition": lambda df: quartile_partition(df, 'exemption_days_hist_due to_your_medical_conditions', 0)},
        {"name": "q1", "condition": lambda df: quartile_partition(df, 'exemption_days_hist_due to_your_medical_conditions', 1)},
        {"name": "q2", "condition": lambda df: quartile_partition(df, 'exemption_days_hist_due to_your_medical_conditions', 2)},
        {"name": "q3", "condition": lambda df: quartile_partition(df, 'exemption_days_hist_due to_your_medical_conditions', 3)},
    ],
    "threshold": 0.05},{
    'name': 'children',
    'partitions': [
        {"name": "0", "condition": lambda df: df['relationship_child_current_number'] == 0},
        {"name": "1", "condition": lambda df: df['relationship_child_current_number'] == 1},
        {"name": "2", "condition": lambda df: df['relationship_child_current_number'] == 2},
        {"name": "3", "condition": lambda df: df['relationship_child_current_number'] == 3},
    ],
    "threshold": 0.05},{
    'name': 'social',
    'partitions': [
        {"name": "social_0", "condition": lambda df: df['pla_history_social_effort'] < 0.5},
        {"name": "social_1", "condition": lambda df: df['pla_history_social_effort'] >= 0.5}
    ],
    "threshold": 0.03},{
    'name': 'gender',
    'partitions': [ 
        {"name": "m", "condition": lambda df: df['person_gender_woman'] < 0.5},
        {"name": "f", "condition": lambda df: df['person_gender_woman'] >= 0.5}
    ],
    "threshold": 0.01}
]

# %%
# Classic ML performance
from sklearn.metrics import classification_report, confusion_matrix, balanced_accuracy_score

def ML_evaluation(model, X_test, y_test, runs=10, sample=5000):

    print("Classic ML Evaluation")
    acc_list = []
    reports = []
    confusion_matrices = []
    for run in range(runs):
        
        data_sample = X_test.sample(n = sample)

        partition_labels = y_test.loc[data_sample.index] 

        if not data_sample.empty:
            # Predictions using the model
            predictions = model.predict(data_sample)

            # Calculate accuracy for this partition
            accuracy = balanced_accuracy_score(partition_labels, predictions)
            acc_list.append(accuracy)
            reports.append(classification_report(partition_labels, predictions, output_dict=True))
            confusion_matrices.append(confusion_matrix(partition_labels, predictions))

    print("Final Results")
    print(f"Average accuracy: {np.mean(acc_list)}")

    weighted_precision = [r['weighted avg']['precision'] for r in reports]
    weighted_recall = [r['weighted avg']['recall'] for r in reports]

    print("Average Weighted Precision:", np.mean(weighted_precision))
    print("Average Weighted Recall:", np.mean(weighted_recall))
    
    stacked = np.stack(confusion_matrices, axis=0)
    print(f"Average confusion:\n {np.mean(stacked, axis=0)}")

# %% [markdown]
# ### Load and test the models

# %%
# Let's load the dataset
data = pd.read_csv('../data/synth_data_for_testing.csv')
details = pd.read_csv('../data/data_description.csv', encoding='latin1')

# Rename columns to english for ease of use
data.rename(columns=dict(zip(details['Feature (nl)'], details['Feature (en)'])), inplace=True)
#data.drop(columns=["Ja", "Nee"], inplace=True)
data.fillna(data.mean(), inplace=True)

# Let's specify the features and the target
y_test = data['checked'].astype(int)
X_test = data.drop(['checked'], axis=1)
X_test = X_test.astype(np.float32)

# %%
# Wrap session in .predict() model
class OnnxWrapper():
    def __init__(self, session):
        self.session = session
    def predict(self, X):
        return self.session.run(None, {'X': X.values.astype(np.float32)})[0]

# %% [markdown]
# ### Our models

# %%
# Let's load our models
import onnxruntime as rt

m1 = OnnxWrapper(rt.InferenceSession("../model/bogdan/model1.onnx"))
m2 = OnnxWrapper(rt.InferenceSession("../model/bogdan/model2.onnx"))

# %%
ML_evaluation(m1, X_test, y_test)
# Out:
# Classic ML Evaluation
# Final Results
# Average accuracy: 0.7528397355228884
# Average Weighted Precision: 0.920665759678028
# Average Weighted Recall: 0.9260400000000001
# Average confusion:
#  [[4362.2  138.4]
#  [ 231.4  268. ]]

# %%
ML_evaluation(m2, X_test, y_test)
# Out:
# Classic ML Evaluation
# Final Results
# Average accuracy: 0.596740892863608
# Average Weighted Precision: 0.8876435277833437
# Average Weighted Recall: 0.9075799999999999
# Average confusion:
#  [[4433.6   64.5]
#  [ 397.6  104.3]]

# %%
# Debug EP
b_e_passed, b_e_failed = equivalence_partitioning_test(m1, X_test, y_test, partition_tests, debug=True);
print("m2")
b_e_passed, b_e_failed = equivalence_partitioning_test(m2, X_test, y_test, partition_tests, debug=True);
# Out:
# Partition on : age
# Max diff: 0.2066891737240578
# Threshold: 0.1
# FAILED ❌
#
# Partition on : language
# Max diff: 0.12134036147835264
# Threshold: 0.05
# FAILED ❌
#
# Partition on : medical
# Max diff: 0.12505561257307854
# Threshold: 0.05
# FAILED ❌
#
# Partition on : children
# Max diff: 0.06769296979389092
# Threshold: 0.05
# FAILED ❌
#
# Partition on : social
# Max diff: 0.0494056530649192
# Threshold: 0.03
# FAILED ❌
#
# Partition on : gender
# Max diff: 0.02021868190617701
# Threshold: 0.01
# FAILED ❌
#
# m2
# Partition on : age
# Max diff: 0.0438221146406234
# Threshold: 0.1
# PASSED ✅
#
# Partition on : language
# Max diff: 0.017386034230201828
# Threshold: 0.05
# PASSED ✅
#
# Partition on : medical
# Max diff: 0.017593503422670423
# Threshold: 0.05
# PASSED ✅
#
# Partition on : children
# Max diff: 0.02067300849471352
# Threshold: 0.05
# PASSED ✅
#
# Partition on : social
# Max diff: 0.023651964921343423
# Threshold: 0.03
# PASSED ✅
#
# Partition on : gender
# Max diff: 0.000417404886810864
# Threshold: 0.01
# PASSED ✅

# %%
# Debug MT
b_e_passed, b_e_failed = metamorphic_test(m1, X_test, y_test, metamorphic_relations, debug=True);
print("m2")
b_e_passed, b_e_failed = metamorphic_test(m2, X_test, y_test, metamorphic_relations, debug=True);
# Out:
# Test: age
# permutation test
# Mean diff: 0.06052000000000003
# Threshold: 0.03
# FAILED ❌
#
# perturbation test
# Mean diff: 0.07225999999999999
# Threshold: 0.02
# FAILED ❌
#
# Test: language
# permutation test
# Mean diff: 0.057419999999999985
# Threshold: 0.03
# FAILED ❌
#
# perturbation test
# Mean diff: 0.016480000000000005
# Threshold: 0.01
# FAILED ❌
#
# Test: medical
# permutation test
# Mean diff: 0.07186
# Threshold: 0.02
# FAILED ❌
#
# perturbation test
# Mean diff: 0.07466000000000002
# Threshold: 0.02
# FAILED ❌
#
# Test: children
# permutation test
# Mean diff: 0.04518000000000001
# Threshold: 0.02
# FAILED ❌
#
# Test: social
# permutation test
# Mean diff: 0.047819999999999994
# Threshold: 0.02
# FAILED ❌
#
# Test: gender
# permutation test
# Mean diff: 0.04748000000000002
# Threshold: 0.02
# FAILED ❌
#
# m2
# Test: age
# permutation test
# Mean diff: 0.017220000000000034
# Threshold: 0.03
# PASSED ✅
#
# perturbation test
# Mean diff: 0.007099999999999984
# Threshold: 0.02
# PASSED ✅
#
# Test: language
# permutation test
# Mean diff: 0.016620000000000013
# Threshold: 0.03
# PASSED ✅
#
# perturbation test
# Mean diff: 0.003899999999999981
# Threshold: 0.01
# PASSED ✅
#
# Test: medical
# permutation test
# Mean diff: 0.0041799999999999945
# Threshold: 0.02
# PASSED ✅
#
# perturbation test
# Mean diff: 0.0016799999999999927
# Threshold: 0.02
# PASSED ✅
#
# Test: children
# permutation test
# Mean diff: 0.0002599999999999936
# Threshold: 0.02
# PASSED ✅
#
# Test: social
# permutation test
# Mean diff: 0.006040000000000001
# Threshold: 0.02
# PASSED ✅
#
# Test: gender
# permutation test
# Mean diff: 0.0035600000000000076
# Threshold: 0.02
# PASSED ✅

# %%
# Fairness testing for m1
b_m_passed, b_m_failed = metamorphic_test(m1, X_test, y_test, metamorphic_relations)
b_e_passed, b_e_failed = equivalence_partitioning_test(m1, X_test, y_test, partition_tests);
b_t_passed = b_m_passed + b_e_passed
b_t_failed = b_m_failed + b_e_failed
b_total = b_t_passed + b_t_failed
print(f"Passed {b_t_passed}/{b_total}")
print(f"Failed {b_t_failed}/{b_total}")
# Out:
# Test: age
# permutation test
# FAILED ❌
#
# perturbation test
# FAILED ❌
#
# Test: language
# permutation test
# FAILED ❌
#
# perturbation test
# FAILED ❌
#
# Test: medical
# permutation test
# FAILED ❌
#
# perturbation test
# FAILED ❌
#
# Test: children
# permutation test
# FAILED ❌
#
# Test: social
# permutation test
# FAILED ❌
#
# Test: gender
# permutation test
# FAILED ❌
#
# Partition on : age
# FAILED ❌
#
# Partition on : language
# FAILED ❌
#
# Partition on : medical
# FAILED ❌
#
# Partition on : children
# FAILED ❌
#
# Partition on : social
# FAILED ❌
#
# Partition on : gender
# FAILED ❌
#
# Passed 0/15
# Failed 15/15

# %%
# Fairness testing for m2
g_m_passed, g_m_failed = metamorphic_test(m2, X_test, y_test, metamorphic_relations)
g_e_passed, g_e_failed = equivalence_partitioning_test(m2, X_test, y_test, partition_tests);
g_t_passed = g_m_passed + g_e_passed
g_t_failed = g_m_failed + g_e_failed
g_total = g_t_passed + g_t_failed
print(f"Passed {g_t_passed}/{g_total}")
print(f"Failed {g_t_failed}/{g_total}")
# Out:
# Test: age
# permutation test
# PASSED ✅
#
# perturbation test
# PASSED ✅
#
# Test: language
# permutation test
# PASSED ✅
#
# perturbation test
# PASSED ✅
#
# Test: medical
# permutation test
# PASSED ✅
#
# perturbation test
# PASSED ✅
#
# Test: children
# permutation test
# PASSED ✅
#
# Test: social
# permutation test
# PASSED ✅
#
# Test: gender
# permutation test
# PASSED ✅
#
# Partition on : age
# PASSED ✅
#
# Partition on : language
# PASSED ✅
#
# Partition on : medical
# PASSED ✅
#
# Partition on : children
# PASSED ✅
#
# Partition on : social
# PASSED ✅
#
# Partition on : gender
# PASSED ✅
#
# Passed 15/15
# Failed 0/15

# %%
print(f"Model 1 passed {b_t_passed}/{b_total}")
print(f"Model 2 passed {g_t_passed}/{g_total}")
# Out:
# Model 1 passed 0/15
# Model 2 passed 15/15

# %% [markdown]
# ### The other team's models

# %%
# Let's load lenka's team's models
import onnxruntime as rt

m1 = OnnxWrapper(rt.InferenceSession("../model/lenka/model1.onnx"))
m2 = OnnxWrapper(rt.InferenceSession("../model/lenka/model2.onnx"))

# %%
ML_evaluation(m1, X_test, y_test)
# Out:
# Classic ML Evaluation
# Final Results
# Average accuracy: 0.5783692528738024
# Average Weighted Precision: 0.8701346428416358
# Average Weighted Recall: 0.8976600000000001
# Average confusion:
#  [[4399.   104.8]
#  [ 406.9   89.3]]

# %%
ML_evaluation(m2, X_test, y_test)
# Out:
# Classic ML Evaluation
# Final Results
# Average accuracy: 0.5792736676957936
# Average Weighted Precision: 0.868609117952593
# Average Weighted Recall: 0.8960800000000001
# Average confusion:
#  [[4388.8  111.9]
#  [ 407.7   91.6]]

# %%
# Debug EP
b_e_passed, b_e_failed = equivalence_partitioning_test(m1, X_test, y_test, partition_tests, debug=True);
print("m2")
b_e_passed, b_e_failed = equivalence_partitioning_test(m2, X_test, y_test, partition_tests, debug=True);
# Out:
# Partition on : age
# Max diff: 0.056756893580401535
# Threshold: 0.1
# PASSED ✅
#
# Partition on : language
# Max diff: 0.023773118514498412
# Threshold: 0.05
# PASSED ✅
#
# Partition on : medical
# Max diff: 0.008266240601251647
# Threshold: 0.05
# PASSED ✅
#
# Partition on : children
# Max diff: 0.0191222699075135
# Threshold: 0.05
# PASSED ✅
#
# Partition on : social
# Max diff: 0.02343510136977579
# Threshold: 0.03
# PASSED ✅
#
# Partition on : gender
# Max diff: 0.004939303758861563
# Threshold: 0.01
# PASSED ✅
#
# m2
# Partition on : age
# Max diff: 0.038731818835393506
# Threshold: 0.1
# PASSED ✅
#
# Partition on : language
# Max diff: 0.03459576058287715
# Threshold: 0.05
# PASSED ✅
#
# Partition on : medical
# Max diff: 0.013924210056242912
# Threshold: 0.05
# PASSED ✅
#
# Partition on : children
# Max diff: 0.019363555385615475
# Threshold: 0.05
# PASSED ✅
#
# Partition on : social
# Max diff: 0.020730577372524116
# Threshold: 0.03
# PASSED ✅
#
# Partition on : gender
# Max diff: 0.007877329656562411
# Threshold: 0.01
# PASSED ✅

# %%
# Debug MT
b_e_passed, b_e_failed = metamorphic_test(m1, X_test, y_test, metamorphic_relations, debug=True);
print("m2")
b_e_passed, b_e_failed = metamorphic_test(m2, X_test, y_test, metamorphic_relations, debug=True);
# Out:
# Test: age
# permutation test
# Mean diff: 0.01634
# Threshold: 0.03
# PASSED ✅
#
# perturbation test
# Mean diff: 0.010240000000000027
# Threshold: 0.02
# PASSED ✅
#
# Test: language
# permutation test
# Mean diff: 0.022219999999999972
# Threshold: 0.03
# PASSED ✅
#
# perturbation test
# Mean diff: 0.003759999999999997
# Threshold: 0.01
# PASSED ✅
#
# Test: medical
# permutation test
# Mean diff: 0.0043199999999999905
# Threshold: 0.02
# PASSED ✅
#
# perturbation test
# Mean diff: 0.0025599999999999954
# Threshold: 0.02
# PASSED ✅
#
# Test: children
# permutation test
# Mean diff: 0.0012400000000000078
# Threshold: 0.02
# PASSED ✅
#
# Test: social
# permutation test
# Mean diff: 0.0048999999999999825
# Threshold: 0.02
# PASSED ✅
#
# Test: gender
# permutation test
# Mean diff: 0.02246
# Threshold: 0.02
# FAILED ❌
#
# m2
# Test: age
# permutation test
# Mean diff: 0.01771999999999997
# Threshold: 0.03
# PASSED ✅
#
# perturbation test
# Mean diff: 0.00990000000000001
# Threshold: 0.02
# PASSED ✅
#
# Test: language
# permutation test
# Mean diff: 0.02240000000000002
# Threshold: 0.03
# PASSED ✅
#
# perturbation test
# Mean diff: 0.0047999999999999935
# Threshold: 0.01
# PASSED ✅
#
# Test: medical
# permutation test
# Mean diff: 0.0026599999999999957
# Threshold: 0.02
# PASSED ✅
#
# perturbation test
# Mean diff: 0.001839999999999975
# Threshold: 0.02
# PASSED ✅
#
# Test: children
# permutation test
# Mean diff: 0.0014799999999999924
# Threshold: 0.02
# PASSED ✅
#
# Test: social
# permutation test
# Mean diff: 0.006659999999999988
# Threshold: 0.02
# PASSED ✅
#
# Test: gender
# permutation test
# Mean diff: 0.021720000000000007
# Threshold: 0.02
# FAILED ❌

# %%
# Fairness testing for m1
b_m_passed, b_m_failed = metamorphic_test(m1, X_test, y_test, metamorphic_relations)
b_e_passed, b_e_failed = equivalence_partitioning_test(m1, X_test, y_test, partition_tests);
b_t_passed = b_m_passed + b_e_passed
b_t_failed = b_m_failed + b_e_failed
b_total = b_t_passed + b_t_failed
print(f"Passed {b_t_passed}/{b_total}")
print(f"Failed {b_t_failed}/{b_total}")
# Out:
# Test: age
# permutation test
# PASSED ✅
#
# perturbation test
# PASSED ✅
#
# Test: language
# permutation test
# PASSED ✅
#
# perturbation test
# PASSED ✅
#
# Test: medical
# permutation test
# PASSED ✅
#
# perturbation test
# PASSED ✅
#
# Test: children
# permutation test
# PASSED ✅
#
# Test: social
# permutation test
# PASSED ✅
#
# Test: gender
# permutation test
# FAILED ❌
#
# Partition on : age
# PASSED ✅
#
# Partition on : language
# PASSED ✅
#
# Partition on : medical
# PASSED ✅
#
# Partition on : children
# PASSED ✅
#
# Partition on : social
# PASSED ✅
#
# Partition on : gender
# PASSED ✅
#
# Passed 14/15
# Failed 1/15

# %%
# Fairness testing for m2
g_m_passed, g_m_failed = metamorphic_test(m2, X_test, y_test, metamorphic_relations)
g_e_passed, g_e_failed = equivalence_partitioning_test(m2, X_test, y_test, partition_tests);
g_t_passed = g_m_passed + g_e_passed
g_t_failed = g_m_failed + g_e_failed
g_total = g_t_passed + g_t_failed
print(f"Passed {g_t_passed}/{g_total}")
print(f"Failed {g_t_failed}/{g_total}")
# Out:
# Test: age
# permutation test
# PASSED ✅
#
# perturbation test
# PASSED ✅
#
# Test: language
# permutation test
# PASSED ✅
#
# perturbation test
# PASSED ✅
#
# Test: medical
# permutation test
# PASSED ✅
#
# perturbation test
# PASSED ✅
#
# Test: children
# permutation test
# PASSED ✅
#
# Test: social
# permutation test
# PASSED ✅
#
# Test: gender
# permutation test
# FAILED ❌
#
# Partition on : age
# PASSED ✅
#
# Partition on : language
# PASSED ✅
#
# Partition on : medical
# PASSED ✅
#
# Partition on : children
# PASSED ✅
#
# Partition on : social
# PASSED ✅
#
# Partition on : gender
# PASSED ✅
#
# Passed 14/15
# Failed 1/15

# %%
print(f"Model 1 passed {b_t_passed}/{b_total}")
print(f"Model 2 passed {g_t_passed}/{g_total}")
# Out:
# Model 1 passed 14/15
# Model 2 passed 14/15
